# %% [markdown]
# # Assignment 4: Data Cleaning for Tableau Public Viz

# %% [markdown]
# ### Load the Necessary Libraries

# %%
# Load necessary libraries
import pandas as pd

# %% [markdown]
# ### STEP 1: Load the Datasets (1996 to 2023)
#
# For a more effecient way to load the datasets between 1996 and 2023, we can use a for loop to load the necessary datasets.

# %%
# Define the base file path and years
base_path = '../../../02_activities/assignments/assignment_4/data/'
years = range(2023, 1995, -1)

# Dictionary to hold data for each year
data = {}

# Loop through each year and load the corresponding dataset with specified encoding
for year in years:
    file_path = f'{base_path}en-{year}-pssd.csv'
    try:
        data[f'data_{year}'] = pd.read_csv(file_path, encoding='latin1')  # or try 'iso-8859-1', 'cp1252'
    except UnicodeDecodeError:
        print(f"Error decoding {file_path}")

# Print out the keys of the dictionary to verify which files were loaded
print(data.keys())
# Out:
# dict_keys(['data_2023', 'data_2022', 'data_2021', 'data_2020', 'data_2019', 'data_2018', 'data_2017', 'data_2016', 'data_2015', 'data_2014', 'data_2013', 'data_2012', 'data_2011', 'data_2010', 'data_2009', 'data_2008', 'data_2007', 'data_2006', 'data_2005', 'data_2004', 'data_2003', 'data_2002', 'data_2001', 'data_2000', 'data_1999', 'data_1998', 'data_1997', 'data_1996'])

# %% [markdown]
# ### STEP 2: Inspecting the Data

# %%
# Inspect the first few rows of each dataset
for year in years:
    print(f"Data for {year}:")
    print(data[f'data_{year}'].head(), "\n")
# Out:
# Data for 2023:
#                   ï»¿Sector Last Name   First Name      Salary  Benefits  \
# 0  Ontario Power Generation  Hartwick      Kenneth  1925372.00   7539.84
# 1  Ontario Power Generation   Miniere    Dominique  1194532.69   3268.80
# 2  Ontario Power Generation  Martelli      Michael   972746.99   3178.08
# 3  Ontario Power Generation   Butcher      Nicolle   894783.33   1286.88
# 4  Ontario Power Generation   Ginther  Christopher   889925.01   7127.40
#
#                    Employer  \
# 0  Ontario Power Generation
# 1  Ontario Power Generation
# 2  Ontario Power Generation
# 3  Ontario Power Generation
# 4  Ontario Power Generation
#
#                                             JobTitle  Year
# 0              President and Chief Executive Officer  2023
# 1                             Chief Strategy Officer  2023
# 2                             Chief Projects Officer  2023
# 3                           Chief Operations Officer  2023
# 4  Executive Vice President Business Strategy and...  2023
#
# Data for 2022:
#   ï»¿Sector   Last Name First Name  Salary paid  Taxable benefits  \
# 0  Colleges      Abboud      Nadim    117071.57            112.52
# 1  Colleges     Adedeji    Odunayo    105261.35              0.00
# 2  Colleges       Agate    Jeffrey    138647.76            432.26
# 3  Colleges  Aikin-Ayre      Sarah    103242.86            321.82
# 4  Colleges      Akanbi    Olaleye    108663.18              0.00
#
#                                            Employer  \
# 0  Algonquin College Of Applied Arts and Technology
# 1  Algonquin College Of Applied Arts and Technology
# 2  Algonquin College Of Applied Arts and Technology
# 3  Algonquin College Of Applied Arts and Technology
# 4  Algonquin College Of Applied Arts and Technology
#
#                                            Job Title  Calendar year
# 0                                          Professor           2022
# 1  Internet Technology Change Management Speciali...           2022
# 2        Associate Director Student Support Services           2022
# 3                             Business Administrator           2022
# 4                   Manager, Enterprise Applications           2022
#
# Data for 2021:
#   ï»¿Sector  Last Name First Name     Salary  Benefits  \
# 0  Colleges     Abboud      Nadim  116977.21    126.77
# 1  Colleges      Agate    Jeffrey  138280.53    392.33
# 2  Colleges  Al Dabbah      Rayan  107206.59     21.77
# 3  Colleges  Alexander       Doug  115377.97    126.77
# 4  Colleges  Alexander      Tamra  116834.24     74.36
#
#                                            Employer  \
# 0  Algonquin College Of Applied Arts and Technology
# 1  Algonquin College Of Applied Arts and Technology
# 2  Algonquin College Of Applied Arts and Technology
# 3  Algonquin College Of Applied Arts and Technology
# 4  Algonquin College Of Applied Arts and Technology
#
#                                      Job Title  Year
# 0                                    Professor  2021
# 1  Associate Director Student Support Services  2021
# 2                                    Professor  2021
# 3                                    Professor  2021
# 4                                    Professor  2021
#
# Data for 2020:
#   ï»¿Sector Last name First name       Salary Benefits  \
# 0  Colleges     Aarts      Cheri  $113,586.57   $71.01
# 1  Colleges   Aaslepp       Drew  $113,685.85  $117.26
# 2  Colleges      Abba    Corinne  $102,214.17  $117.36
# 3  Colleges    Abbott      Brian  $102,855.46  $117.36
# 4  Colleges    Abbott   Kathleen  $160,854.89  $326.33
#
#                                             Employer  \
# 0    Fanshawe College Of Applied Arts and Technology
# 1  Humber College Institute Of Technology and Adv...
# 2  George Brown College Of Applied Arts and Techn...
# 3  Conestoga College Institute Of Technology and ...
# 4  George Brown College Of Applied Arts and Techn...
#
#                                         Job title  Year
# 0                                       Professor  2020
# 1                                       Professor  2020
# 2                                       Librarian  2020
# 3                                       Professor  2020
# 4  Associate Dean, Centre for Continuous Learning  2020
#
# Data for 2019:
#   ï»¿Sector Last Name First Name  Salary Paid  Taxable Benefits  \
# 0  Colleges     Aarts      Cheri    111359.14             68.04
# 1  Colleges   Aaslepp       Drew    104315.38            110.88
# 2  Colleges     Abbas      Sadiq    111442.39             68.16
# 3  Colleges    Abbott   Kathleen    162020.08            283.34
# 4  Colleges    Abbott  Timothy M    116898.76             68.04
#
#                                             Employer  \
# 0    Fanshawe College Of Applied Arts and Technology
# 1  Humber College Institute Of Technology and Adv...
# 2   Algonquin College Of Applied Arts and Technology
# 3  George Brown College Of Applied Arts and Techn...
# 4      Seneca College Of Applied Arts and Technology
#
#                                         Job Title  Calendar Year
# 0                                       Professor           2019
# 1                                       Professor           2019
# 2                                       Professor           2019
# 3  Associate Dean, Centre for Continuous Learning           2019
# 4                                       Professor           2019
#
# Data for 2018:
#     ï»¿Sector    Last Name First Name  Salary Paid  Taxable Benefits  \
# 0  CollegesÂ        Jensen     Cheryl    337533.24           3408.12
# 1  CollegesÂ         Brule     Claude    230976.76            374.96
# 2  CollegesÂ   Wotherspoon       Doug    230788.38            186.58
# 3  CollegesÂ        Mcnair      Duane    221744.64            366.12
# 4  CollegesÂ       Stanbra      Laura    221744.64            366.12
#
#             Employer                                  Job Title  Calendar Year
# 0  Algonquin College                                  President           2018
# 1  Algonquin College             Senior Vice President Academic           2018
# 2  Algonquin College     Vice President Innovation and Strategy           2018
# 3  Algonquin College  Vice President Finance and Administration           2018
# 4  Algonquin College            Vice President Student Services           2018
#
# Data for 2017:
#   ï»¿Sector Last Name    First Name  Salary Paid  Taxable Benefits  \
# 0  Colleges  Abiscott         Alexa    197073.24           2033.69
# 1  Colleges       Ahn       Song Ho    114331.63             51.57
# 2  Colleges    Aitken        Sharon    118650.76           1250.00
# 3  Colleges       Ali       Shirook    104398.32            101.50
# 4  Colleges   Allcott  Austin Micha    124307.70           1264.54
#
#                                             Employer  \
# 0  Sheridan College Institute of Technology and A...
# 1  Sheridan College Institute of Technology and A...
# 2  Sheridan College Institute of Technology and A...
# 3  Sheridan College Institute of Technology and A...
# 4  Sheridan College Institute of Technology and A...
#
#                                          Job Title  Calendar Year
# 0  General Counsel And Information Privacy Officer           2017
# 1     Visualization Researcher - Part-Time Faculty           2017
# 2                Director Development and Campaign           2017
# 3                                        Professor           2017
# 4                                             Dean           2017
#
# Data for 2016:
#   ï»¿Sector  Last Name  First Name  Salary Paid  Taxable Benefits  \
# 0  Colleges      Abbas       Sadiq    105595.39             84.24
# 1  Colleges     Abboud       Nadim    108393.10            126.96
# 2  Colleges      Agate  Jeffery M.    125779.64            325.58
# 3  Colleges  Al-Azzawi       Abdul    105595.41             84.24
# 4  Colleges  Alexander        Doug    105595.41            126.96
#
#             Employer                                     Job Title  \
# 0  Algonquin College                                     Professor
# 1  Algonquin College                                     Professor
# 2  Algonquin College  Associate Director, Student Support Services
# 3  Algonquin College                                     Professor
# 4  Algonquin College                                     Professor
#
#    Calendar Year
# 0         2016.0
# 1         2016.0
# 2         2016.0
# 3         2016.0
# 4         2016.0
#
# Data for 2015:
#                             ï»¿Sector Last Name First Name  Salary Paid  \
# 0  Government of Ontario - Ministries     Aniol    Richard    106143.80
# 1  Government of Ontario - Ministries   Bennett    Phyllis    116374.20
# 2  Government of Ontario - Ministries     Bliss       Rose    104306.14
# 3  Government of Ontario - Ministries     Bozzo     Sandra    129825.76
# 4  Government of Ontario - Ministries      Carr    Douglas    192375.37
#
#   Taxable Benefits            Employer  \
# 0          $177.35  Aboriginal Affairs
# 1          $187.86  Aboriginal Affairs
# 2          $177.79  Aboriginal Affairs
# 3          $187.79  Aboriginal Affairs
# 4          $296.82  Aboriginal Affairs
#
#                                            Job Title  Calendar Year
# 0         Senior Negotiator / NÃ©gociateur principal           2015
# 1  Manager, Issues Management & Media Relations /...           2015
# 2  Manager, Performance Measures & Data / Chef, m...           2015
# 3  Manager, Aboriginal Relationships / Chef, rela...           2015
# 4  Assistant Deputy Minister, Negotiations & Reco...           2015
#
# Data for 2014:
#                             ï»¿Sector Last name First Name  Salary Paid  \
# 0  Government of Ontario - Ministries    Almond     Margot    123153.63
# 1  Government of Ontario - Ministries     Aniol    Richard    102860.59
# 2  Government of Ontario - Ministries   Bennett    Phyllis    114399.48
# 3  Government of Ontario - Ministries      Bird       Anne    103033.91
# 4  Government of Ontario - Ministries     Bliss       Rose    102045.84
#
#    Taxable Benefits            Employer  \
# 0            204.96  Aboriginal Affairs
# 1            173.98  Aboriginal Affairs
# 2            189.54  Aboriginal Affairs
# 3            176.37  Aboriginal Affairs
# 4            175.66  Aboriginal Affairs
#
#                                            Job title  Calendar year
# 0  Director, Corporate Management / Directrice, g...           2014
# 1         Senior Negotiator / NÃ©gociateur principal           2014
# 2  Manager, Issues Management and Media Relations...           2014
# 3                         Team Lead / Chef d'Ã©quipe           2014
# 4  Manager, Performance Measures and Data / Chef,...           2014
#
# Data for 2013:
#   ï»¿Sector  Last Name       First Name  Salary Paid  Taxable Benefits  \
# 0  Colleges      ABBAS            SADIQ    102185.98            114.48
# 1  Colleges      AGATE  JEFFERY MICHAEL    108564.60            371.78
# 2  Colleges  AL-AZZAWI            ABDUL    102185.98            173.44
# 3  Colleges    ALLAIRE              DAN    103738.79            355.81
# 4  Colleges      ALLEN           IAN D.    104255.25            114.48
#
#             Employer                                  Job Title  Calendar Year
# 0  Algonquin College                                  Professor           2013
# 1  Algonquin College  Manager, Counselling and Testing Services           2013
# 2  Algonquin College                                  Professor           2013
# 3  Algonquin College           Manager, Client Support Services           2013
# 4  Algonquin College                                  Professor           2013
#
# Data for 2012:
#   ï»¿Sector  Last Name       First Name  Salary Paid  Taxable Benefits  \
# 0  Colleges      ABBAS            SADIQ    102185.98            119.88
# 1  Colleges      AGATE  JEFFERY MICHAEL    104656.60            335.15
# 2  Colleges  AL-AZZAWI            ABDUL    103133.47            185.88
# 3  Colleges      ALLAN             GAIL    104893.10            185.88
# 4  Colleges      ALLEN           IAN D.    104140.79            119.88
#
#             Employer                                  Job Title  Calendar Year
# 0  Algonquin College                                  Professor           2012
# 1  Algonquin College  Manager, Counselling and Testing Services           2012
# 2  Algonquin College                                  Professor           2012
# 3  Algonquin College                                  Professor           2012
# 4  Algonquin College                                  Professor           2012
#
# Data for 2011:
#   ï»¿Sector  Last Name First Name Salary Paid  Taxable Benefits  \
# 0  Colleges      ABBAS      SADIQ  $100,763.83          $120.42
# 1  Colleges     ADAMYK       MIKE  $100,814.67          $175.50
# 2  Colleges  AL-AZZAWI      ABDUL  $103,485.49          $186.42
# 3  Colleges      ALLAN       GAIL  $103,485.49          $186.42
# 4  Colleges      ALLEN     IAN D.  $102,692.85          $120.42
#
#             Employer  Job Title  Calendar Year
# 0  Algonquin College  Professor           2011
# 1  Algonquin College  Professor           2011
# 2  Algonquin College  Professor           2011
# 3  Algonquin College  Professor           2011
# 4  Algonquin College  Professor           2011
#
# Data for 2010:
#   ï»¿Sector     Last Name First Name Salary Paid  Taxable Benefits  \
# 0  Colleges       ABRAHAM    STEPHEN  $136,704.67          $547.02
# 1  Colleges         ALLAN       GAIL  $101,464.04          $192.36
# 2  Colleges     ALMUHTADI      WAHAB  $101,464.04          $192.36
# 3  Colleges         AUBUT      JOANN  $120,387.58          $488.13
# 4  Colleges  BALASEVICIUS      DEBRA  $121,202.26          $486.09
#
#             Employer                                          Job Title  \
# 0  Algonquin College  Director, Information Technology Services - Ch...
# 1  Algonquin College                                          Professor
# 2  Algonquin College                                          Professor
# 3  Algonquin College                      Chair, Allied Health Programs
# 4  Algonquin College     Chair, Health and Community Studies Department
#
#    Calendar Year
# 0           2010
# 1           2010
# 2           2010
# 3           2010
# 4           2010
#
# Data for 2009:
#   ï»¿Sector     Last Name First Name Salary Paid  Taxable Benefits  \
# 0  Colleges       ABRAHAM    STEPHEN  $136,794.34          $622.39
# 1  Colleges     ALMUHTADI      WAHAB  $107,007.81          $193.02
# 2  Colleges      ANDERSON     JEREMY  $104,586.89          $193.02
# 3  Colleges         AUBUT      JOANN  $123,287.56          $552.82
# 4  Colleges  BALASEVICIUS      DEBRA  $123,020.57          $552.82
#
#             Employer                                          Job Title  \
# 0  Algonquin College  Director, Information Technology Services - Ch...
# 1  Algonquin College                                          Professor
# 2  Algonquin College                                          Professor
# 3  Algonquin College                      Chair, Allied Health Programs
# 4  Algonquin College       Chair, Health & Community Studies Department
#
#    Calendar Year
# 0           2009
# 1           2009
# 2           2009
# 3           2009
# 4           2009
#
# Data for 2008:
#   ï»¿Sector     Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges       ABRAHAM    STEPHEN  $135,053.28          $716.86
# 1  Colleges  ALEXANDRIDIS    ANGELOS  $128,836.81          $200.92
# 2  Colleges         AUBUT      JOANN  $125,064.36          $651.15
# 3  Colleges  BALASEVICIUS      DEBRA  $116,035.76          $609.98
# 4  Colleges        BARKER    GERRY A  $176,482.85          $887.80
#
#             Employer                                          Job Title  \
# 0  Algonquin College  Director, Information Technology Services/Chie...
# 1  Algonquin College                                          Professor
# 2  Algonquin College               Executive Dean, Academic Development
# 3  Algonquin College       Chair, Health & Community Studies Department
# 4  Algonquin College                    Vice President, Human Resources
#
#    Calendar Year
# 0           2008
# 1           2008
# 2           2008
# 3           2008
# 4           2008
#
# Data for 2007:
#   ï»¿Sector     Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges       ABRAHAM    STEPHEN  $131,895.52          $760.97
# 1  Colleges         AUBUT      JOANN  $111,736.56          $650.84
# 2  Colleges  BALASEVICIUS      DEBRA  $118,839.63          $693.74
# 3  Colleges        BARKER    GERRY A  $152,607.80          $888.56
# 4  Colleges       BOOGERD        JAN  $111,736.56          $650.84
#
#             Employer                                          Job Title  \
# 0  Algonquin College  Director, Information Technology Services/Chie...
# 1  Algonquin College                      Chair, Allied Health Programs
# 2  Algonquin College       Chair, Health & Community Studies Department
# 3  Algonquin College  Executive Dean, Faculty of Health, Public Safe...
# 4  Algonquin College  Chair, Architecture/Civil/Geographic Informati...
#
#    Calendar Year
# 0           2007
# 1           2007
# 2           2007
# 3           2007
# 4           2007
#
# Data for 2006:
#         ï»¿Sector  Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Crown Agencies      BROWN       GREG  $108,982.53       $14,679.09
# 1  Crown Agencies  GALLAGHER    JOCELYN  $110,895.04          $424.54
# 2  Crown Agencies         IP    STEPHEN  $107,843.92        $6,422.84
# 3  Crown Agencies     JACKIW      RANDY  $163,357.45        $9,089.10
# 4  Crown Agencies   MCMORRIS       MIKE  $110,629.35          $430.18
#
#    Employer                                 Job Title  Calendar Year
# 0  Agricorp  Executive Director, Business Development           2006
# 1  Agricorp                 Director, Human Resources           2006
# 2  Agricorp          Director, Information Technology           2006
# 3  Agricorp                    Chef Executive Officer           2006
# 4  Agricorp                      Director, Operations           2006
#
# Data for 2005:
#      Sector     Last Name First Name   Salary Paid Taxable Benefits  \
# 0  Colleges       ABRAHAM    STEPHEN  $102,543.28          $549.29
# 1  Colleges         AUBUT      JOANN  $100,391.51          $524.04
# 2  Colleges  BALASEVICIUS      DEBRA  $104,561.36          $557.28
# 3  Colleges        BARKER   GERRY A.  $133,321.69          $625.58
# 4  Colleges       BOOGERD        JAN  $104,561.36          $557.28
#
#             Employer                                 Job Title  Calendar Year
# 0  Algonquin College       Dir., Information Technology Srvcs.           2005
# 1  Algonquin College             Chair, Allied Health Services           2005
# 2  Algonquin College          Chair, Health & Community Srvcs.           2005
# 3  Algonquin College  Exec. Dean, Hlth., Public Safety & Comm.           2005
# 4  Algonquin College             Chair, Architecture/Civil/GIS           2005
#
# Data for 2004:
#   ï»¿Sector Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges    BARKER   GERRY A.  $107,089.79          $138.69
# 1  Colleges     BROCK      BARRY  $111,294.44           $41.04
# 2  Colleges     BRULE     CLAUDE  $106,718.45          $134.70
# 3  Colleges     BURKE       MARK  $119,677.73            $0.00
# 4  Colleges    CARTER      GARRY  $114,386.18           $67.87
#
#             Employer                               Job Title  Calendar Year
# 0  Algonquin College  Dean, Police & Public Safety Institute           2004
# 1  Algonquin College          Dir., Information Tech. Srvcs.           2004
# 2  Algonquin College                 Chair, Computer Studies           2004
# 3  Algonquin College                      Sr. Account, Exec.           2004
# 4  Algonquin College                               Professor           2004
#
# Data for 2003:
#      Sector  Last Name First Name   Salary Paid Taxable Benefits  \
# 0  Colleges      BROCK      BARRY  $101,518.74          $159.68
# 1  Colleges      BURKE       MARK  $102,603.21            $0.00
# 2  Colleges    CORMIER      MARIE  $106,057.76          $289.76
# 3  Colleges  DWORSCHAK    HERMANN  $108,217.26          $181.89
# 4  Colleges   FAULKNER      KAREN  $103,459.99          $181.89
#
#             Employer                                 Job Title  Calendar Year
# 0  Algonquin College    Director, Information Technology Srvcs           2003
# 1  Algonquin College                  Senior Account Executive           2003
# 2  Algonquin College  Dean, School of Health & Community Srvcs           2003
# 3  Algonquin College                                  Academic           2003
# 4  Algonquin College                                  Academic           2003
#
# Data for 2002:
#      Sector Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges   CORMIER      MARIE  $103,293.85          $159.68
# 1  Colleges   DONOVEN      NANCY  $109,189.06            $0.00
# 2  Colleges   GILLETT     ROBERT  $198,917.04       $18,925.24
# 3  Colleges     GREER     JANINE  $102,960.90            $0.00
# 4  Colleges  HAMILTON       JOHN  $155,342.27          $194.10
#
#             Employer                                 Job Title  Calendar Year
# 0  Algonquin College  Dean, School of Health & Community Srvcs           2002
# 1  Algonquin College                    Senior Sales Executive           2002
# 2  Algonquin College                                 President           2002
# 3  Algonquin College             Manager, Customized Contracts           2002
# 4  Algonquin College          Vice-President, Finance & Admin.           2002
#
# Data for 2001:
#      Sector     Surname First Name  Salary Paid Taxable Benefits  \
# 0  Colleges     CORMIER      MARIE  $100,892.35          $162.85
# 1  Colleges     GILLETT     ROBERT  $187,623.89       $10,430.37
# 2  Colleges    HAMILTON       JOHN  $143,139.95          $224.02
# 3  Colleges      HANSON   RAYMONDE  $123,784.96          $224.72
# 4  Colleges  PAPADOLIAS       NICK  $105,082.20          $192.17
#
#             Employer                                Position  Calendar Year
# 0  Algonquin College  Dean, School of Health & Comm. Studies           2001
# 1  Algonquin College                               President           2001
# 2  Algonquin College                    VP, Finance & Admin.           2001
# 3  Algonquin College       Vice President, Academic Services           2001
# 4  Algonquin College          Director, Educational Services           2001
#
# Data for 2000:
#      Sector Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges   GILLETT     ROBERT  $166,098.26       $10,826.56
# 1  Colleges  HAMILTON       JOHN  $118,978.35        $5,433.30
# 2  Colleges    HANSON   RAYMONDE  $119,337.72        $5,440.56
# 3  Colleges    MORASH   FRANCINE  $114,069.20            $0.00
# 4  Colleges  PATERSON      JANET  $104,738.65          $157.56
#
#             Employer                          Job Title  Calendar Year
# 0  Algonquin College                          President           2000
# 1  Algonquin College                 VP, Finance&Admin.           2000
# 2  Algonquin College  Vice President, Academic Services           2000
# 3  Algonquin College          Sales Training Consultant           2000
# 4  Algonquin College          Director, Business Sector           2000
#
# Data for 1999:
#      Sector Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges    CONROD    WILLIAM  $103,428.18        $5,375.72
# 1  Colleges   GILLETT     ROBERT  $147,293.02       $11,311.15
# 2  Colleges  HAMILTON       JOHN  $113,891.12        $5,434.30
# 3  Colleges    HANSON   RAYMONDE  $117,512.24        $5,455.36
# 4  Colleges      REID       RICK  $102,559.35          $491.28
#
#             Employer                          Job Title  Calendar Year
# 0  Algonquin College                    VP, Development           1999
# 1  Algonquin College                          President           1999
# 2  Algonquin College                 VP, Finance&Admin.           1999
# 3  Algonquin College  Vice President, Academic Services           1999
# 4  Algonquin College      Director, Hospitality&Tourism           1999
#
# Data for 1998:
#      Sector  Last Name First Name  Salary Paid Taxable Benefits  \
# 0  Colleges    GILLETT     ROBERT  $126,843.08       $10,723.40
# 1  Colleges     HANSON   RAYMONDE  $109,742.68        $5,542.60
# 2  Colleges  MCTIERNAN    TIMOTHY  $121,300.08          $227.04
# 3  Colleges   JOHNSTON       JOHN  $108,741.12          $401.84
# 4  Colleges    SUMMERS    WILLIAM  $102,496.12          $678.22
#
#              Employer                          Job Title  Calendar Year
# 0   Algonquin College                          President           1998
# 1   Algonquin College  Vice President, Academic Services           1998
# 2    Canadore College                          President           1998
# 3  Centennial College                          President           1998
# 4  Centennial College          Vice President, Academics           1998
#
# Data for 1997:
#      Sector   Last Name First Name   Salary Paid Taxable Benefits  \
# 0  Colleges     Gillett     Robert  $126,843.08       $15,237.07
# 1  Colleges      Hanson   Raymonde  $102,604.32        $5,502.22
# 2  Colleges  Mitchelson     Robert  $106,199.60        $5,528.80
# 3  Colleges     Crombie      Glenn  $115,811.32        $2,995.34
# 4  Colleges   Henderson  Catherine  $127,313.00       $19,034.97
#
#              Employer                       Job Title  Calendar Year
# 0           Algonquin                       President           1997
# 1           Algonquin                  V.P., Academic           1997
# 2           Algonquin  V.P., Finance & Administration           1997
# 3            Cambrian                       President           1997
# 4  Centennial College                       President           1997
#
# Data for 1996:
#                           Sector Last Name First Name  Salary Paid  \
# 0  OTHER PUBLIC SECTOR EMPLOYERS   Kendall      Perry  $194,890.40
# 1  OTHER PUBLIC SECTOR EMPLOYERS      Rehm    Juergen  $115,603.62
# 2  OTHER PUBLIC SECTOR EMPLOYERS      Room      Robin  $149,434.48
# 3         ONTARIO PUBLIC SERVICE      KNOX      KEN W  $109,382.92
# 4                      HOSPITALS     Cliff      Bruce  $110,309.00
#
#   Taxable Benefits                             Employer  \
# 0          $711.24        Addiction Research Foundation
# 1          $403.41        Addiction Research Foundation
# 2          $512.58        Addiction Research Foundation
# 3        $4,921.68   Agriculture,Food and Rural Affairs
# 4        $3,157.00  Ajax and Pickering General Hospital
#
#                                            Job Title  Calendar Year
# 0                                    President & CEO           1996
# 1  Dir., Soc. Eval. Research & Act. Dir., Clin. R...           1996
# 2     V.P., Research & Coordinator, Intern. Programs           1996
# 3                                    Deputy Minister           1996
# 4                                    President & CEO           1996

# %% [markdown]
# ### STEP 3: Checking for Missing Values

# %%
# Check for missing values in each dataset
for year in years:
    missing_values = data[f'data_{year}'].isnull().sum()
    print(f"Missing values in data for {year}:\n{missing_values}\n")
# Out:
# Missing values in data for 2023:
# ï»¿Sector     0
# Last Name     0
# First Name    0
# Salary        0
# Benefits      0
# Employer      0
# JobTitle      0
# Year          0
# dtype: int64
#
# Missing values in data for 2022:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary paid         0
# Taxable benefits    0
# Employer            0
# Job Title           0
# Calendar year       0
# dtype: int64
#
# Missing values in data for 2021:
# ï»¿Sector     0
# Last Name     0
# First Name    0
# Salary        0
# Benefits      0
# Employer      0
# Job Title     0
# Year          0
# dtype: int64
#
# Missing values in data for 2020:
# ï»¿Sector     0
# Last name     0
# First name    0
# Salary        0
# Benefits      0
# Employer      0
# Job title     0
# Year          0
# dtype: int64
#
# Missing values in data for 2019:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2018:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2017:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2016:
# ï»¿Sector            0
# Last Name            0
# First Name           0
# Salary Paid          0
# Taxable Benefits     1
# Employer             0
# Job Title            0
# Calendar Year       65
# dtype: int64
#
# Missing values in data for 2015:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2014:
# ï»¿Sector           0
# Last name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job title           0
# Calendar year       0
# dtype: int64
#
# Missing values in data for 2013:
# ï»¿Sector           0
# Last Name           0
# First Name          1
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2012:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2011:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2010:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2009:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2008:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2007:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2006:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2005:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2004:
# ï»¿Sector           0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2003:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2002:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2001:
# Sector              0
# Surname             0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Position            0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 2000:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 1999:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 1998:
# Sector              0
# Last Name           0
# First Name          1
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 1997:
# Sector              0
# Last Name           0
# First Name          0
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           1
# Calendar Year       0
# dtype: int64
#
# Missing values in data for 1996:
# Sector              0
# Last Name           0
# First Name          1
# Salary Paid         0
# Taxable Benefits    0
# Employer            0
# Job Title           0
# Calendar Year       0
# dtype: int64

# %% [markdown]
# Upon inspection, there is a discrepancy in the coloumn titles for the "Salary" between years 2020 and 2023. The years between 1996 and 2019 are titled "Salary Paid" while the years 2020 to 2023 are titled "Salary" and "Salary paid". So the next step is to rename the columns to all match.

# %% [markdown]
# ### STEP 4: Standardize Column Names

# %%
# List of years where the column needs to be renamed
years_to_rename = range(2023, 1995, -1)

# Loop through each year to standardize and rename the columns
for year in years_to_rename:
    # Standardize column names to lowercase and strip any whitespace
    data[f'data_{year}'].columns = [col.strip().lower() for col in data[f'data_{year}'].columns]
    
    # Rename the columns
    data[f'data_{year}'] = data[f'data_{year}'].rename(columns={
        "salary": "salary paid",
        "benefits": "taxable benefits",
        "calendar year": "year",
        "ï»¿sector": "sector"
    })

# Verify the changes
for year in years_to_rename:
    print(f"Columns for {year}: {data[f'data_{year}'].columns}")
# Out:
# Columns for 2023: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'jobtitle', 'year'],
#       dtype='object')
# Columns for 2022: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2021: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2020: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2019: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2018: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2017: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2016: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2015: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2014: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2013: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2012: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2011: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2010: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2009: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2008: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2007: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2006: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2005: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2004: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2003: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2002: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 2001: Index(['sector', 'surname', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'position', 'year'],
#       dtype='object')
# Columns for 2000: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 1999: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 1998: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 1997: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')
# Columns for 1996: Index(['sector', 'last name', 'first name', 'salary paid', 'taxable benefits',
#        'employer', 'job title', 'year'],
#       dtype='object')

# %% [markdown]
# ### STEP 5: Cleaning Sector Column

# %%
# Set to collect all unique sector names
unique_sectors = set()

# Loop through each year and collect unique sector names
for year in years:
    if 'sector' in data[f'data_{year}'].columns:
        unique_sectors.update(data[f'data_{year}']['sector'].unique())

# Convert the set to a list and sort it for better readability
unique_sectors = sorted(unique_sectors)

# Display all unique sector names
print("Unique sector names:")
for sector in unique_sectors:
    print(sector)
# Out:
# Unique sector names:
# COLLEGES
# CROWN AGENCIES
# Colleges
# Colleges
# CollegesÂ
# Crown Agencies
# Government of Ontario - Judiciary
# Government of Ontario - Legislative Assembly & Offices
# Government of Ontario - Legislative Assembly and Offices
# Government of Ontario - Ministries
# Government of Ontario : Judiciary
# Government of Ontario : Legislative Assembly
# Government of Ontario : Legislative Assembly and Offices
# Government of Ontario : Ministries
# Government of Ontario â Judiciary
# Government of Ontario â Legislative Assembly and Offices
# Government of Ontario â Ministries
# HOSPITALS
# Hospitals
# Hospitals & Boards of Public Health
# Hospitals and Boards of Public Health
# Hydro One & Ontario Power Generation
# Hydro One and Ontario Power Generation
# MUNICIPALITIES
# Municipalities
# Municipalities & Services
# Municipalities and Services
# ONTARIO PUBLIC SERVICE
# OTHER PUBLIC SECTOR EMPLOYERS
# Ontario Power Generation
# Ontario Public Service
# Other Public Sector
# Other Public Sector Employers
# Other Public Sector Employers
# SCHOOL BOARDS
# School Boards
# Seconded (Advanced Education and Skills Development)*
# Seconded (Attorney General)
# Seconded (Attorney General)*
# Seconded (Cabinet Office)*
# Seconded (Children & Youth Services)*
# Seconded (Children and Youth Services)
# Seconded (Children and Youth Services)*
# Seconded (Children, Community and Social Services)
# Seconded (Children, Community and Social Services)*
# Seconded (Citizenship & Immigration)*
# Seconded (Citizenship and Multiculturalism)*
# Seconded (Colleges and Universities)
# Seconded (Comm. Safety and Corr. Services)*
# Seconded (Comm. Safety/CorrectionalÂ Srvcs.)*
# Seconded (Community & Social Services)*
# Seconded (Community Safety & Correctional Services)*
# Seconded (Community Safety and Correctional Services)*
# Seconded (Community Safety/Correctional Srvcs.)*
# Seconded (Community and Social Services)*
# Seconded (Economic Development & Trade)*
# Seconded (Economic Development and Innovation)*
# Seconded (Economic Development and Trade)*
# Seconded (Education)
# Seconded (Education)*
# Seconded (Energy and Infrastructure)*
# Seconded (Energy)*
# Seconded (Environment)*
# Seconded (Health & Long-Term Care)*
# Seconded (Health & LongâTerm Care)*
# Seconded (Health Promotion & Sport)*
# Seconded (Health Promotion)*
# Seconded (Health and Long-Term Care)
# Seconded (Health and Long-Term Care)*
# Seconded (Health)
# Seconded (Health)*
# Seconded (Labour)
# Seconded (Labour)*
# Seconded (Ministry of Labour)*
# Seconded (Municipal Affairs and Housing)
# Seconded (Research & Innovation)*
# Seconded (Research and Innovation)*
# Seconded (Solicitor General)
# Seconded (Solicitor General)*
# Seconded (Tourism, Culture & Sport)*
# Seconded (Training, Colleges & Universities)*
# Seconded (Training, Colleges and Universities)
# Seconded (Training, Colleges and Universities)*
# Seconded (Transportation)*
# UNIVERSITIES
# Universities
# Universities - UniversitÃ©s

# %%
sector_mapping = {
    "COLLEGES": "Colleges",
    "Colleges ": "Colleges",
    "CollegesÂ ": "Colleges",
    "CollegesÂ": "Colleges",
    "CROWN AGENCIES": "Crown Agencies",
    "Crown Agencies": "Crown Agencies",
    "Government of Ontario - Judiciary": "Government of Ontario - Judiciary",
    "Government of Ontario - Legislative Assembly & Offices": "Government of Ontario - Legislative Assembly and Offices",
    "Government of Ontario : Judiciary": "Government of Ontario - Judiciary",
    "Government of Ontario : Legislative Assembly": "Government of Ontario - Legislative Assembly and Offices",
    "Government of Ontario : Legislative Assembly and Offices": "Government of Ontario - Legislative Assembly and Offices",
    "Government of Ontario : Ministries": "Government of Ontario - Ministries",
    "Government of Ontario â Judiciary": "Government of Ontario - Judiciary",
    "Government of Ontario â Legislative Assembly and Offices": "Government of Ontario - Legislative Assembly and Offices",
    "Government of Ontario â Ministries": "Government of Ontario - Ministries",
    "HOSPITALS": "Hospitals and Boards of Public Health",
    "Hospitals": "Hospitals and Boards of Public Health",
    "Hospitals & Boards of Public Health": "Hospitals and Boards of Public Health",
    "Hospitals and Boards of Public Health": "Hospitals and Boards of Public Health",
    "Hydro One & Ontario Power Generation": "Hydro One and Ontario Power Generation",
    "Hydro One and Ontario Power Generation": "Hydro One and Ontario Power Generation",
    "MUNICIPALITIES": "Municipalities",
    "Municipalities": "Municipalities",
    "Municipalities & Services": "Municipalities",
    "Municipalities and Services": "Municipalities",
    "ONTARIO PUBLIC SERVICE": "Ontario Public Service",
    "OTHER PUBLIC SECTOR EMPLOYERS": "Other Public Sector",
    "Ontario Public Service": "Ontario Public Service",
    "Other Public Sector Employers": "Other Public Sector",
    "Other Public Sector Employers ": "Other Public Sector",
    "SCHOOL BOARDS": "School Boards",
    "School Boards": "School Boards",
    "Seconded (Advanced Education and Skills Development)*": "Seconded (Advanced Education and Skills Development)",
    "Seconded (Attorney General)*": "Seconded (Attorney General)",
    "Seconded (Cabinet Office)*": "Seconded (Cabinet Office)",
    "Seconded (Children & Youth Services)*": "Seconded (Children, Community and Social Services)",
    "Seconded (Children and Youth Services)*": "Seconded (Children, Community and Social Services)",
    "Seconded (Children, Community and Social Services)*": "Seconded (Children, Community and Social Services)",
    "Seconded (Citizenship & Immigration)*": "Seconded (Citizenship and Multiculturalism)",
    "Seconded (Citizenship and Multiculturalism)*": "Seconded (Citizenship and Multiculturalism)",
    "Seconded (Colleges and Universities)*": "Seconded (Colleges and Universities)",
    "Seconded (Comm. Safety and Corr. Services)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Comm. Safety/CorrectionalÂ Srvcs.)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Community & Social Services)*": "Seconded (Community and Social Services)",
    "Seconded (Community Safety & Correctional Services)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Community Safety/Correctional Srvcs.)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Economic Development & Trade)*": "Seconded (Economic Development and Trade)",
    "Seconded (Economic Development and Innovation)*": "Seconded (Economic Development and Trade)",
    "Seconded (Economic Development and Trade)*": "Seconded (Economic Development and Trade)",
    "Seconded (Education)*": "Seconded (Education)",
    "Seconded (Energy and Infrastructure)*": "Seconded (Energy and Infrastructure)",
    "Seconded (Energy)*": "Seconded (Energy and Infrastructure)",
    "Seconded (Environment)*": "Seconded (Environment)",
    "Seconded (Health & LongâTerm Care)*": "Seconded (Health)",
    "Seconded (Health & Long-Term Care)*": "Seconded (Health)",
    "Seconded (Health Promotion & Sport)*": "Seconded (Health)",
    "Seconded (Health Promotion)*": "Seconded (Health)",
    "Seconded (Health and Long-Term Care)*": "Seconded (Health)",
    "Seconded (Health)*": "Seconded (Health)",
    "Seconded (Labour)*": "Seconded (Labour)",
    "Seconded (Ministry of Labour)*": "Seconded (Labour)",
    "Seconded (Municipal Affairs and Housing)*": "Seconded (Municipal Affairs and Housing)",
    "Seconded (Research & Innovation)*": "Seconded (Research and Innovation)",
    "Seconded (Solicitor General)*": "Seconded (Solicitor General)",
    "Seconded (Tourism, Culture & Sport)*": "Seconded (Tourism, Culture and Sport)",
    "Seconded (Training, Colleges and Universities)*": "Seconded (Training, Colleges and Universities)",
    "Seconded (Training, Colleges & Universities)*": "Seconded (Training, Colleges and Universities)",
    "Seconded (Transportation)*": "Seconded (Transportation)",
    "UNIVERSITIES": "Universities",
    "Universities": "Universities",
    "Universities - UniversitÃ©s": "Universities",
    "Universities - Universités": "Universities"
    
}

# %%
# Apply the mapping to standardize sector names
for year in years:
    if 'sector' in data[f'data_{year}'].columns:
        data[f'data_{year}']['sector'] = data[f'data_{year}']['sector'].replace(sector_mapping)

# Verify the changes by printing unique sector names again
unique_sectors = set()
for year in years:
    if 'sector' in data[f'data_{year}'].columns:
        unique_sectors.update(data[f'data_{year}']['sector'].unique())

unique_sectors = sorted(unique_sectors)
print("Unique sector names after standardization:")
for sector in unique_sectors:
    print(sector)
# Out:
# Unique sector names after standardization:
# Colleges
# CollegesÂ
# Crown Agencies
# Government of Ontario - Judiciary
# Government of Ontario - Legislative Assembly and Offices
# Government of Ontario - Ministries
# Hospitals and Boards of Public Health
# Hydro One and Ontario Power Generation
# Municipalities
# Ontario Power Generation
# Ontario Public Service
# Other Public Sector
# School Boards
# Seconded (Advanced Education and Skills Development)
# Seconded (Attorney General)
# Seconded (Cabinet Office)
# Seconded (Children and Youth Services)
# Seconded (Children, Community and Social Services)
# Seconded (Citizenship and Multiculturalism)
# Seconded (Colleges and Universities)
# Seconded (Comm. Safety/CorrectionalÂ Srvcs.)*
# Seconded (Community Safety and Correctional Services)
# Seconded (Community Safety and Correctional Services)*
# Seconded (Community and Social Services)
# Seconded (Community and Social Services)*
# Seconded (Economic Development and Trade)
# Seconded (Education)
# Seconded (Energy and Infrastructure)
# Seconded (Energy)
# Seconded (Environment)
# Seconded (Health Promotion)
# Seconded (Health and Long-Term Care)
# Seconded (Health)
# Seconded (Labour)
# Seconded (Municipal Affairs and Housing)
# Seconded (Research and Innovation)
# Seconded (Research and Innovation)*
# Seconded (Solicitor General)
# Seconded (Tourism, Culture and Sport)
# Seconded (Training, Colleges and Universities)
# Seconded (Transportation)
# Universities

# %%
sector_mapping.update({
    "CollegesÂ ": "Colleges",
    "Seconded (Comm. Safety/CorrectionalÂ Srvcs.)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Community Safety and Correctional Services)*": "Seconded (Community Safety and Correctional Services)",
    "Seconded (Community and Social Services)*": "Seconded (Children, Community and Social Services)",
    "Seconded (Community and Social Services)": "Seconded (Children, Community and Social Services)",
    "Seconded (Research and Innovation)*": "Seconded (Research and Innovation)",
    "Seconded (Energy and Infrastructure)": "Seconded (Energy)",
    "Seconded (Children and Youth Services)": "Seconded (Children, Community and Social Services)",
    "Seconded (Health Promotion)": "Seconded (Health)",
    "Seconded (Health and Long-Term Care)": "Seconded (Health)",
    "Hydro One and Ontario Power Generation": "Ontario Power Generation",
    "Seconded (Training, Colleges and Universities)": "Seconded (Colleges and Universities)"
})

# %%
# Apply the updated mapping to standardize sector names
for year in years:
    if 'sector' in data[f'data_{year}'].columns:
        data[f'data_{year}']['sector'] = data[f'data_{year}']['sector'].replace(sector_mapping)

# Verify the changes by printing unique sector names again
unique_sectors = set()
for year in years:
    if 'sector' in data[f'data_{year}'].columns:
        unique_sectors.update(data[f'data_{year}']['sector'].unique())

unique_sectors = sorted(unique_sectors)
print("Unique sector names after final standardization:")
for sector in unique_sectors:
    print(sector)
# Out:
# Unique sector names after final standardization:
# Colleges
# Crown Agencies
# Government of Ontario - Judiciary
# Government of Ontario - Legislative Assembly and Offices
# Government of Ontario - Ministries
# Hospitals and Boards of Public Health
# Municipalities
# Ontario Power Generation
# Ontario Public Service
# Other Public Sector
# School Boards
# Seconded (Advanced Education and Skills Development)
# Seconded (Attorney General)
# Seconded (Cabinet Office)
# Seconded (Children, Community and Social Services)
# Seconded (Citizenship and Multiculturalism)
# Seconded (Colleges and Universities)
# Seconded (Community Safety and Correctional Services)
# Seconded (Economic Development and Trade)
# Seconded (Education)
# Seconded (Energy)
# Seconded (Environment)
# Seconded (Health)
# Seconded (Labour)
# Seconded (Municipal Affairs and Housing)
# Seconded (Research and Innovation)
# Seconded (Solicitor General)
# Seconded (Tourism, Culture and Sport)
# Seconded (Transportation)
# Universities

# %% [markdown]
# ### STEP 6: Concatenating DataFrames

# %%
# Concatenate all DataFrames into a single DataFrame
all_data = pd.concat([data[f'data_{year}'] for year in years], ignore_index=True)

# Save the merged DataFrame to a CSV file
output_file_path = '../../../02_activities/assignments/assignment_4/data/merged_data_1996_2023.csv'
all_data.to_csv(output_file_path, index=False)

# Confirm the save
print(f"Merged data saved to {output_file_path}")
# Out:
# Merged data saved to ../../../02_activities/assignments/assignment_4/data/merged_data_1996_2023.csv
